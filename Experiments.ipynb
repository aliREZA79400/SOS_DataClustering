# %%
""" 
def crawler models 
  Args :
    Folder Path of models

{ 1. Show experiments of article : The convergence curves of algorithms for data set Scale(Best Results) ,
                                    omputation time (Mean ± Std.) of all algorithms using each test dataset,
                                    Ranks achieved by the Friedman test
                                    Anova test for data set CMC (-)
                                    Adjusted p-values for the Friedman test (SOS is the control method)
    2. Visualize best models                                 
    }
"""

# %%
from mealpy.utils import io

import os
from utils import datasets

import numpy as np

# %%
dataset , targ = datasets.retu_dataset("Iris_Dataset")
# Out:
# Iris

# %%
def find_pkls(folder_path):
    targets = []
    for root, dirs, files in os.walk(folder_path):
        for name in files:
            
            if name.endswith((".pkl")) and name[8:12] == "Iris":
                
                file_path = os.path.join(root, name)

                model = io.load_model(file_path)
                
                targets.append((model.g_best.target.fitness,name[-5:-4]))
    return targets

# %% [markdown]
# ## Best( SOS vs PSO ) on Iris

# %% [markdown]
# ### Show SOS on Iris

# %%
targets_iris_sos = find_pkls("/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/SOS")

targets_iris_sos
# Out:
# [(96.54385375976562, '0'),
#  (96.54052734375, '1'),
#  (96.54080200195312, '2'),
#  (96.54055786132812, '3'),
#  (96.54058074951172, '4')]

# %%
sorted(targets_iris_sos,key = lambda x: x[0])
# Out:
# [(96.54052734375, '1'),
#  (96.54055786132812, '3'),
#  (96.54058074951172, '4'),
#  (96.54080200195312, '2'),
#  (96.54385375976562, '0')]

# %%
best_iris_path_with_sos = "/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/SOS/Models/results_Iris_Dataset_1.pkl"

best_iris_sos = io.load_model(best_iris_path_with_sos)

# %%
from utils import visualize

# %%
vis_iris = visualize.Visualize(3 , dataset=dataset , target=targ ,
                               g_best=best_iris_sos.g_best)

# %%
vis_iris.draw_all()

# %%
visualize.saver_figurs(best_iris_sos,saver_path_figur="/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/Figs/SOS_figs")

# %%
best_iris_sos.history.list_epoch_time
# Out:
# [1.1270191639996483,
#  1.0698457250000502,
#  0.5196964530005062,
#  0.513248093000584,
#  0.54469875399991,
#  0.5173047610005597,
#  0.517251338999813,
#  0.5385203389996605,
#  0.929501522999999,
#  1.1231260679996922,
#  0.7488132600001336,
#  0.5150867560005281,
#  0.5210144369993941,
#  0.5294209720004801,
#  0.5178039639995404,
#  0.5467281829996864,
#  0.6660375780002141,
#  1.111218158000156,
#  1.0127905250001277,
#  0.5175255969998034,
#  0.5111452159999317,
#  0.5143007050000961,
#  0.5337934119997954,
#  0.5208440810001775,
#  0.5123909660005666,
#  0.8951895610007341,
#  1.141200834999836,
#  0.748075035000511,
#  0.5139981359998274,
#  0.5122582509993663,
#  0.513239192000583,
#  0.5119648580002831,
#  0.5220767629998591,
#  0.544551484999829,
#  1.10783187800007,
#  1.1180338980002489,
#  0.5201541170008568,
#  0.5160048540001299,
#  0.5506328269993901,
#  0.5330695620004917,
#  0.5332472239997514,
#  0.5289873980000266,
#  0.9151916250002614,
#  1.1272208730006241,
# ...

# %% [markdown]
# ### Show PSO on Iris

# %%
targets_iris_pso = find_pkls("/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/PSO")

sorted(targets_iris_pso,key=lambda x: x[0])
# Out:
# [(102.50120544433594, '1'),
#  (103.73594665527344, '4'),
#  (105.90214538574219, '0'),
#  (115.89306640625, '2'),
#  (131.0392608642578, '3')]

# %%
best_iris_path_with_pso = "/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/PSO/results_Iris_Dataset_1.pkl"

best_iris_pso = io.load_model(best_iris_path_with_pso)

# %%
vis_iris_pso = visualize.Visualize(3,dataset=dataset,target=targ,
                                   g_best=best_iris_pso.g_best)

# %%
vis_iris_pso.draw_all()

# %%
visualize.saver_figurs(best_iris_pso,saver_path_figur="/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/Figs/PSO_figs")

# %% [markdown]
# #### Time

# %%
np.sum(best_iris_sos.history.list_epoch_time)
# Out:
# 136.8175358339995

# %%
np.sum(best_iris_pso.history.list_epoch_time)
# Out:
# 59.61622178700077

# %% [markdown]
# ## SOS vs ABC on Breast Cancer

# %% [markdown]
# ### Show ABC on Breast Canser

# %%
dataset_brest , targ_breast = datasets.retu_dataset("Breast_Cancer")

# %%
def find_pkls_new(folder_path,dataset_name):
    targets = []
    for root, dirs, files in os.walk(folder_path):
        for name in files:
            
            if name.endswith((".pkl")) and (dataset_name in name) :
                
                file_path = os.path.join(root, name)

                model = io.load_model(file_path)
                
                targets.append((model.g_best.target.fitness,name[-5:-4],file_path))
    return sorted(targets, key=lambda x: x[0])

# %%
targets_breast_ABC = find_pkls_new("/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/ABC",
                                   dataset_name="Breast_Cancer")

# %%
targets_breast_ABC
# Out:
# [(149493.734375,
#   '2',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/ABC/results_ABC_Breast_Cancer_2.pkl'),
#  (149495.953125,
#   '0',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/ABC/results_ABC_Breast_Cancer_0.pkl'),
#  (149501.203125,
#   '1',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/ABC/results_ABC_Breast_Cancer_1.pkl'),
#  (149511.09375,
#   '4',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/ABC/results_ABC_Breast_Cancer_4.pkl'),
#  (149513.90625,
#   '3',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/ABC/results_ABC_Breast_Cancer_3.pkl')]

# %%
best_breast_ABC = io.load_model(targets_breast_ABC[0][2])

# %%
vis_ABC_breast = visualize.Visualize(2,dataset=dataset_brest,target=targ_breast,
                                    g_best=best_breast_ABC.g_best)

# %%
vis_ABC_breast.draw_all()

# %% [markdown]
# ### Show SOS on Breast Cancer

# %%
SOS_folder_path = "/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/SOS"

# %%
def find_pkls_new_plus(folder_path,dataset_name):
    targets = []
    for root, dirs, files in os.walk(folder_path):
        for name in files:
            
            if name.endswith((".pkl")) and (dataset_name in name) :
                
                file_path = os.path.join(root, name)

                model = io.load_model(file_path)
                
                targets.append((model.g_best.target.fitness,name[-5:-4],file_path))
    return io.load_model(sorted(targets, key=lambda x: x[0])[0][2]) , sorted(targets, key=lambda x: x[0])

# %%
best_breast_SOS_model , list= find_pkls_new_plus(SOS_folder_path,dataset_name="Breast_Cancer")

# %%
list
# Out:
# [(149475.4375,
#   '0',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/SOS/Models/results_Breast_Cancer_0.pkl'),
#  (149485.390625,
#   '4',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/SOS/Models/results_Breast_Cancer_4.pkl'),
#  (149493.40625,
#   '3',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/SOS/Models/results_Breast_Cancer_3.pkl'),
#  (149500.796875,
#   '2',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/SOS/Models/results_Breast_Cancer_2.pkl'),
#  (149533.34375,
#   '1',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/SOS/Models/results_Breast_Cancer_1.pkl')]

# %%
vis_SOS_breasts = visualize.Visualize(2,dataset=dataset_brest,target=targ_breast,
                                      g_best= best_breast_SOS_model.g_best)

# %%
vis_SOS_breasts.draw_all()

# %% [markdown]
# #### Time

# %%
np.sum(best_breast_SOS_model.history.list_epoch_time)
# Out:
# 431.34374734599896

# %%
np.sum(best_breast_ABC.history.list_epoch_time)
# Out:
# 221.2030103210127

# %% [markdown]
# ## SOS vs CS on Wine

# %% [markdown]
# ### Show SOS on Wine

# %%
dataset_wine , targ_win = datasets.retu_dataset("Wine")
# Out:
# this wine dataset

# %%
best_sos_wine , best_sos_wine_list = find_pkls_new_plus(SOS_folder_path,
                                                        dataset_name="Wine")

# %%
best_sos_wine_list
# Out:
# [(16292.72265625,
#   '4',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/SOS/results_Wine_4.pkl'),
#  (16292.908203125,
#   '3',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/SOS/results_Wine_3.pkl'),
#  (16292.95703125,
#   '2',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/SOS/results_Wine_2.pkl'),
#  (16293.01171875,
#   '1',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/SOS/results_Wine_1.pkl'),
#  (16294.4404296875,
#   '0',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/SOS/results_Wine_0.pkl')]

# %%
vis_wine_sos = visualize.Visualize(3,dataset=dataset_wine,target=targ_win,
                                   g_best=best_sos_wine.g_best)

# %%
vis_wine_sos.draw_all()

# %% [markdown]
# ### Show CS on Wine

# %%
CS_folder_path = "/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/CS"

# %%
best_cs_wine , best_cs_wine_list = find_pkls_new_plus(CS_folder_path,dataset_name="Wine")

# %%
best_cs_wine_list
# Out:
# [(16682.84375,
#   '1',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/CS/results_CS_Wine_1.pkl'),
#  (16780.3125,
#   '4',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/CS/results_CS_Wine_4.pkl'),
#  (16973.03125,
#   '3',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/CS/results_CS_Wine_3.pkl'),
#  (17042.171875,
#   '2',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/CS/results_CS_Wine_2.pkl'),
#  (17129.71875,
#   '0',
#   '/media/alireza/SSD/arshad_hosh/ProCode/ADCSOS/CS/results_CS_Wine_0.pkl')]

# %%
vis_cs_wine = visualize.Visualize(3,dataset=dataset_wine,target=targ_win,
                                  g_best=best_cs_wine.g_best)

# %%
vis_cs_wine.draw_all()

# %% [markdown]
# #### Time

# %%
np.sum(best_sos_wine.history.list_epoch_time)
# Out:
# 173.86401384901546

# %%
np.sum(best_cs_wine.history.list_epoch_time)
# Out:
# 57.885071861983306
